# %% [markdown]
# # Fit WMF (weighted matrix factorization) to the binarized ML20M

# %%
import itertools
import os
import sys
os.environ['OPENBLAS_NUM_THREADS'] = '1'

import numpy as np
import pandas as pd
from scipy import sparse

# %%
import content_wmf
import batched_inv_joblib
import rec_eval

# %% [markdown]
# ### Load pre-processed data

# %% [markdown]
# Change this to wherever you saved the pre-processed data following [this notebook](./preprocess_ML20M.ipynb).

# %%
DATA_DIR = '/home/net1/appry001/data/ml-20m/pro'

# %%
unique_uid = list()
with open(os.path.join(DATA_DIR, 'unique_uid.txt'), 'r') as f:
    for line in f:
        unique_uid.append(line.strip())
    
unique_sid = list()
with open(os.path.join(DATA_DIR, 'unique_sid.txt'), 'r') as f:
    for line in f:
        unique_sid.append(line.strip())

# %%
n_items = len(unique_sid)
n_users = len(unique_uid)

print n_users, n_items
# Out:
# 111148 11711

# %%
def load_data(csv_file, shape=(n_users, n_items)):
    tp = pd.read_csv(csv_file)
    timestamps, rows, cols = np.array(tp['timestamp']), np.array(tp['uid']), np.array(tp['sid'])
    #seq = np.concatenate((rows[:, None], cols[:, None], np.ones((rows.size, 1), dtype='int'), timestamps[:, None]), axis=1)
    data = sparse.csr_matrix((np.ones_like(rows), (rows, cols)), dtype=np.int16, shape=shape)
    return data

# %%
train_data = load_data(os.path.join(DATA_DIR, 'train.csv'))

# %%
vad_data = load_data(os.path.join(DATA_DIR, 'validation.csv'))

# %% [markdown]
# ### Train the model

# %%
num_factors = 100
num_iters = 50
batch_size = 1000

n_jobs = 4
lam_theta = lam_beta = 1e-5

# %%
best_ndcg = -np.inf
U_best = None
V_best = None
best_alpha = 0

for alpha in [2, 5, 10, 30, 50]: 
    S = content_wmf.linear_surplus_confidence_matrix(train_data, alpha=alpha)

    U, V, vad_ndcg = content_wmf.factorize(S, num_factors, vad_data=vad_data, num_iters=num_iters, 
                                           init_std=0.01, lambda_U_reg=lam_theta, lambda_V_reg=lam_beta, 
                                           dtype='float32', random_state=98765, verbose=True, 
                                           recompute_factors=batched_inv_joblib.recompute_factors_batched, 
                                           batch_size=batch_size, n_jobs=n_jobs)
    if vad_ndcg > best_ndcg:
        best_ndcg = vad_ndcg
        U_best = U.copy()
        V_best = V.copy()
        best_alpha = alpha
# Out:
# Precompute S^T (if necessary)
#   took 0.146 seconds
# Iteration 0:
# 	Updating user factors: time=16.11
# 	Updating item factors: time=3.96
# rec_eval.py:257: RuntimeWarning: invalid value encountered in divide
#   return DCG / IDCG
# 	Validation NDCG@k: 0.21821
# Iteration 1:
# 	Updating user factors: time=16.00
# 	Updating item factors: time=4.20
# 	Validation NDCG@k: 0.30866
# Iteration 2:
# 	Updating user factors: time=16.28
# 	Updating item factors: time=3.74
# 	Validation NDCG@k: 0.31885
# Iteration 3:
# 	Updating user factors: time=16.71
# 	Updating item factors: time=3.98
# 	Validation NDCG@k: 0.32216
# Iteration 4:
# 	Updating user factors: time=16.33
# 	Updating item factors: time=3.73
# 	Validation NDCG@k: 0.32435
# Iteration 5:
# 	Updating user factors: time=16.85
# 	Updating item factors: time=3.70
# 	Validation NDCG@k: 0.32606
# Iteration 6:
# 	Updating user factors: time=16.68
# 	Updating item factors: time=3.92
# 	Validation NDCG@k: 0.32745
# Iteration 7:
# 	Updating user factors: time=16.94
# 	Updating item factors: time=3.98
# 	Validation NDCG@k: 0.32839
# Iteration 8:
# 	Updating user factors: time=16.39
# 	Updating item factors: time=3.86
# 	Validation NDCG@k: 0.32909
# Iteration 9:
# 	Updating user factors: time=16.71
# 	Updating item factors: time=3.70
# 	Validation NDCG@k: 0.32965
# Iteration 10:
# 	Updating user factors: time=16.83
# 	Updating item factors: time=3.93
# 	Validation NDCG@k: 0.33011
# Iteration 11:
# 	Updating user factors: time=16.86
# 	Updating item factors: time=3.97
# 	Validation NDCG@k: 0.33055
# Iteration 12:
# 	Updating user factors: time=16.23
# 	Updating item factors: time=3.93
# 	Validation NDCG@k: 0.33090
# Iteration 13:
# 	Updating user factors: time=16.76
# 	Updating item factors: time=3.97
# 	Validation NDCG@k: 0.33117
# Iteration 14:
# 	Updating user factors: time=17.14
# 	Updating item factors: time=4.29
# 	Validation NDCG@k: 0.33127
# Iteration 15:
# 	Updating user factors: time=16.65
# 	Updating item factors: time=3.99
# 	Validation NDCG@k: 0.33141
# Iteration 16:
# 	Updating user factors: time=16.90
# 	Updating item factors: time=3.96
# 	Validation NDCG@k: 0.33159
# Iteration 17:
# 	Updating user factors: time=16.71
# 	Updating item factors: time=3.91
# 	Validation NDCG@k: 0.33181
# Iteration 18:
# 	Updating user factors: time=16.82
# 	Updating item factors: time=3.81
# 	Validation NDCG@k: 0.33192
# Iteration 19:
# 	Updating user factors: time=19.77
# 	Updating item factors: time=3.99
# 	Validation NDCG@k: 0.33204
# Iteration 20:
# 	Updating user factors: time=16.51
# 	Updating item factors: time=3.75
# 	Validation NDCG@k: 0.33218
# Iteration 21:
# 	Updating user factors: time=16.53
# 	Updating item factors: time=4.00
# 	Validation NDCG@k: 0.33223
# Iteration 22:
# 	Updating user factors: time=16.74
# 	Updating item factors: time=3.98
# 	Validation NDCG@k: 0.33231
# Iteration 23:
# 	Updating user factors: time=16.77
# 	Updating item factors: time=4.01
# 	Validation NDCG@k: 0.33243
# Iteration 24:
# 	Updating user factors: time=16.94
# 	Updating item factors: time=3.98
# 	Validation NDCG@k: 0.33252
# Iteration 25:
# 	Updating user factors: time=16.74
# 	Updating item factors: time=4.00
# 	Validation NDCG@k: 0.33252
# Iteration 26:
# 	Updating user factors: time=16.72
# 	Updating item factors: time=3.97
# 	Validation NDCG@k: 0.33259
# Iteration 27:
# 	Updating user factors: time=16.58
# 	Updating item factors: time=4.27
# 	Validation NDCG@k: 0.33265
# Iteration 28:
# 	Updating user factors: time=16.86
# 	Updating item factors: time=3.97
# 	Validation NDCG@k: 0.33269
# Iteration 29:
# 	Updating user factors: time=16.79
# 	Updating item factors: time=3.79
# 	Validation NDCG@k: 0.33270
# Iteration 30:
# 	Updating user factors: time=17.10
# 	Updating item factors: time=4.02
# 	Validation NDCG@k: 0.33271
# Iteration 31:
# 	Updating user factors: time=16.64
# 	Updating item factors: time=4.21
# 	Validation NDCG@k: 0.33276
# Iteration 32:
# 	Updating user factors: time=16.83
# 	Updating item factors: time=3.96
# 	Validation NDCG@k: 0.33278
# Iteration 33:
# 	Updating user factors: time=16.73
# 	Updating item factors: time=4.02
# 	Validation NDCG@k: 0.33278
# Iteration 34:
# 	Updating user factors: time=16.78
# 	Updating item factors: time=4.02
# 	Validation NDCG@k: 0.33279
# Iteration 35:
# 	Updating user factors: time=16.77
# 	Updating item factors: time=3.89
# 	Validation NDCG@k: 0.33276
# Precompute S^T (if necessary)
#   took 0.148 seconds
# Iteration 0:
# 	Updating user factors: time=16.63
# 	Updating item factors: time=3.87
# 	Validation NDCG@k: 0.20643
# Iteration 1:
# 	Updating user factors: time=16.41
# 	Updating item factors: time=4.24
# 	Validation NDCG@k: 0.31379
# Iteration 2:
# 	Updating user factors: time=16.78
# 	Updating item factors: time=3.94
# 	Validation NDCG@k: 0.32953
# Iteration 3:
# 	Updating user factors: time=16.35
# 	Updating item factors: time=3.83
# 	Validation NDCG@k: 0.33610
# Iteration 4:
# 	Updating user factors: time=16.88
# 	Updating item factors: time=4.28
# 	Validation NDCG@k: 0.33995
# Iteration 5:
# 	Updating user factors: time=16.50
# 	Updating item factors: time=3.80
# 	Validation NDCG@k: 0.34250
# Iteration 6:
# 	Updating user factors: time=16.71
# 	Updating item factors: time=4.05
# 	Validation NDCG@k: 0.34441
# Iteration 7:
# 	Updating user factors: time=16.38
# 	Updating item factors: time=3.89
# 	Validation NDCG@k: 0.34574
# Iteration 8:
# 	Updating user factors: time=16.74
# 	Updating item factors: time=4.00
# 	Validation NDCG@k: 0.34697
# Iteration 9:
# 	Updating user factors: time=16.44
# 	Updating item factors: time=4.14
# 	Validation NDCG@k: 0.34794
# Iteration 10:
# 	Updating user factors: time=16.89
# 	Updating item factors: time=3.97
# 	Validation NDCG@k: 0.34868
# Iteration 11:
# 	Updating user factors: time=16.63
# 	Updating item factors: time=4.27
# 	Validation NDCG@k: 0.34915
# Iteration 12:
# 	Updating user factors: time=16.76
# 	Updating item factors: time=3.84
# 	Validation NDCG@k: 0.34965
# Iteration 13:
# 	Updating user factors: time=16.41
# 	Updating item factors: time=3.94
# 	Validation NDCG@k: 0.34998
# Iteration 14:
# 	Updating user factors: time=16.81
# 	Updating item factors: time=3.99
# 	Validation NDCG@k: 0.35022
# Iteration 15:
# 	Updating user factors: time=16.61
# 	Updating item factors: time=4.03
# 	Validation NDCG@k: 0.35051
# Iteration 16:
# 	Updating user factors: time=16.77
# 	Updating item factors: time=4.25
# 	Validation NDCG@k: 0.35073
# Iteration 17:
# 	Updating user factors: time=19.46
# 	Updating item factors: time=4.17
# 	Validation NDCG@k: 0.35086
# Iteration 18:
# 	Updating user factors: time=17.45
# 	Updating item factors: time=4.03
# 	Validation NDCG@k: 0.35085
# Precompute S^T (if necessary)
#   took 0.152 seconds
# Iteration 0:
# 	Updating user factors: time=16.86
# 	Updating item factors: time=3.76
# 	Validation NDCG@k: 0.19086
# Iteration 1:
# 	Updating user factors: time=16.34
# 	Updating item factors: time=4.24
# 	Validation NDCG@k: 0.31008
# Iteration 2:
# 	Updating user factors: time=17.05
# 	Updating item factors: time=3.80
# 	Validation NDCG@k: 0.32825
# Iteration 3:
# 	Updating user factors: time=16.28
# 	Updating item factors: time=3.96
# 	Validation NDCG@k: 0.33675
# Iteration 4:
# 	Updating user factors: time=16.82
# 	Updating item factors: time=4.22
# 	Validation NDCG@k: 0.34171
# Iteration 5:
# 	Updating user factors: time=16.48
# 	Updating item factors: time=3.75
# 	Validation NDCG@k: 0.34491
# Iteration 6:
# 	Updating user factors: time=17.45
# 	Updating item factors: time=3.98
# 	Validation NDCG@k: 0.34729
# Iteration 7:
# 	Updating user factors: time=16.44
# 	Updating item factors: time=3.98
# 	Validation NDCG@k: 0.34894
# Iteration 8:
# 	Updating user factors: time=16.85
# 	Updating item factors: time=4.25
# 	Validation NDCG@k: 0.35018
# Iteration 9:
# 	Updating user factors: time=16.63
# 	Updating item factors: time=3.95
# 	Validation NDCG@k: 0.35112
# Iteration 10:
# 	Updating user factors: time=16.57
# 	Updating item factors: time=3.95
# 	Validation NDCG@k: 0.35193
# Iteration 11:
# 	Updating user factors: time=16.52
# 	Updating item factors: time=3.82
# 	Validation NDCG@k: 0.35252
# Iteration 12:
# 	Updating user factors: time=16.94
# 	Updating item factors: time=3.84
# 	Validation NDCG@k: 0.35301
# Iteration 13:
# 	Updating user factors: time=16.67
# 	Updating item factors: time=4.02
# 	Validation NDCG@k: 0.35341
# Iteration 14:
# 	Updating user factors: time=16.92
# 	Updating item factors: time=3.96
# 	Validation NDCG@k: 0.35376
# Iteration 15:
# 	Updating user factors: time=16.56
# 	Updating item factors: time=3.72
# 	Validation NDCG@k: 0.35401
# Iteration 16:
# 	Updating user factors: time=17.74
# 	Updating item factors: time=3.85
# 	Validation NDCG@k: 0.35425
# Iteration 17:
# 	Updating user factors: time=16.52
# 	Updating item factors: time=4.01
# 	Validation NDCG@k: 0.35432
# Iteration 18:
# 	Updating user factors: time=16.81
# 	Updating item factors: time=4.19
# 	Validation NDCG@k: 0.35450
# Iteration 19:
# 	Updating user factors: time=17.22
# 	Updating item factors: time=3.99
# 	Validation NDCG@k: 0.35468
# Iteration 20:
# 	Updating user factors: time=16.85
# 	Updating item factors: time=3.95
# 	Validation NDCG@k: 0.35480
# Iteration 21:
# 	Updating user factors: time=16.51
# 	Updating item factors: time=3.77
# 	Validation NDCG@k: 0.35488
# Iteration 22:
# 	Updating user factors: time=16.87
# 	Updating item factors: time=4.27
# 	Validation NDCG@k: 0.35495
# Iteration 23:
# 	Updating user factors: time=16.64
# 	Updating item factors: time=3.97
# 	Validation NDCG@k: 0.35495
# Precompute S^T (if necessary)
#   took 0.153 seconds
# Iteration 0:
# 	Updating user factors: time=16.64
# 	Updating item factors: time=3.73
# 	Validation NDCG@k: 0.15258
# Iteration 1:
# 	Updating user factors: time=16.82
# 	Updating item factors: time=4.00
# 	Validation NDCG@k: 0.28689
# Iteration 2:
# 	Updating user factors: time=16.91
# 	Updating item factors: time=3.83
# 	Validation NDCG@k: 0.30727
# Iteration 3:
# 	Updating user factors: time=16.67
# 	Updating item factors: time=3.73
# 	Validation NDCG@k: 0.31711
# Iteration 4:
# 	Updating user factors: time=16.86
# 	Updating item factors: time=3.94
# 	Validation NDCG@k: 0.32329
# Iteration 5:
# 	Updating user factors: time=16.80
# 	Updating item factors: time=4.22
# 	Validation NDCG@k: 0.32746
# Iteration 6:
# 	Updating user factors: time=16.85
# 	Updating item factors: time=3.87
# 	Validation NDCG@k: 0.33009
# Iteration 7:
# 	Updating user factors: time=19.69
# 	Updating item factors: time=3.82
# 	Validation NDCG@k: 0.33200
# Iteration 8:
# 	Updating user factors: time=16.97
# 	Updating item factors: time=3.97
# 	Validation NDCG@k: 0.33327
# Iteration 9:
# 	Updating user factors: time=19.81
# 	Updating item factors: time=4.02
# 	Validation NDCG@k: 0.33427
# Iteration 10:
# 	Updating user factors: time=16.81
# 	Updating item factors: time=4.25
# 	Validation NDCG@k: 0.33511
# Iteration 11:
# 	Updating user factors: time=16.91
# 	Updating item factors: time=4.02
# 	Validation NDCG@k: 0.33563
# Iteration 12:
# 	Updating user factors: time=17.00
# 	Updating item factors: time=3.98
# 	Validation NDCG@k: 0.33594
# Iteration 13:
# 	Updating user factors: time=16.71
# 	Updating item factors: time=4.11
# 	Validation NDCG@k: 0.33628
# Iteration 14:
# 	Updating user factors: time=16.55
# 	Updating item factors: time=4.29
# 	Validation NDCG@k: 0.33653
# Iteration 15:
# 	Updating user factors: time=16.81
# 	Updating item factors: time=4.32
# 	Validation NDCG@k: 0.33665
# Iteration 16:
# 	Updating user factors: time=16.84
# 	Updating item factors: time=4.00
# 	Validation NDCG@k: 0.33677
# Iteration 17:
# 	Updating user factors: time=16.86
# 	Updating item factors: time=4.33
# 	Validation NDCG@k: 0.33692
# Iteration 18:
# 	Updating user factors: time=17.00
# 	Updating item factors: time=4.33
# 	Validation NDCG@k: 0.33702
# Iteration 19:
# 	Updating user factors: time=16.59
# 	Updating item factors: time=4.02
# 	Validation NDCG@k: 0.33714
# Iteration 20:
# 	Updating user factors: time=16.86
# 	Updating item factors: time=3.96
# 	Validation NDCG@k: 0.33712
# Precompute S^T (if necessary)
#   took 0.145 seconds
# Iteration 0:
# 	Updating user factors: time=16.86
# 	Updating item factors: time=3.77
# 	Validation NDCG@k: 0.13021
# Iteration 1:
# 	Updating user factors: time=16.57
# 	Updating item factors: time=3.98
# 	Validation NDCG@k: 0.26902
# Iteration 2:
# 	Updating user factors: time=16.67
# 	Updating item factors: time=3.94
# 	Validation NDCG@k: 0.29031
# Iteration 3:
# 	Updating user factors: time=16.64
# 	Updating item factors: time=4.25
# 	Validation NDCG@k: 0.30068
# Iteration 4:
# 	Updating user factors: time=16.33
# 	Updating item factors: time=3.96
# 	Validation NDCG@k: 0.30715
# Iteration 5:
# 	Updating user factors: time=16.82
# 	Updating item factors: time=4.22
# 	Validation NDCG@k: 0.31135
# Iteration 6:
# 	Updating user factors: time=16.71
# 	Updating item factors: time=3.83
# 	Validation NDCG@k: 0.31428
# Iteration 7:
# 	Updating user factors: time=16.61
# 	Updating item factors: time=3.81
# 	Validation NDCG@k: 0.31619
# Iteration 8:
# 	Updating user factors: time=16.64
# 	Updating item factors: time=3.77
# 	Validation NDCG@k: 0.31759
# Iteration 9:
# 	Updating user factors: time=16.45
# 	Updating item factors: time=3.69
# 	Validation NDCG@k: 0.31867
# Iteration 10:
# 	Updating user factors: time=16.60
# 	Updating item factors: time=3.96
# 	Validation NDCG@k: 0.31940
# Iteration 11:
# 	Updating user factors: time=16.54
# 	Updating item factors: time=4.22
# 	Validation NDCG@k: 0.31999
# Iteration 12:
# 	Updating user factors: time=16.68
# 	Updating item factors: time=3.83
# 	Validation NDCG@k: 0.32040
# Iteration 13:
# 	Updating user factors: time=16.66
# 	Updating item factors: time=3.92
# 	Validation NDCG@k: 0.32060
# Iteration 14:
# 	Updating user factors: time=16.71
# 	Updating item factors: time=4.16
# 	Validation NDCG@k: 0.32082
# Iteration 15:
# 	Updating user factors: time=16.50
# 	Updating item factors: time=3.97
# 	Validation NDCG@k: 0.32098
# Iteration 16:
# 	Updating user factors: time=16.56
# 	Updating item factors: time=4.23
# 	Validation NDCG@k: 0.32100
# Iteration 17:
# 	Updating user factors: time=16.66
# 	Updating item factors: time=4.21
# 	Validation NDCG@k: 0.32102
# Iteration 18:
# 	Updating user factors: time=16.68
# 	Updating item factors: time=3.93
# 	Validation NDCG@k: 0.32099

# %%
print(best_alpha, best_ndcg)
# Out:
# (10, 0.35495107675688048)

# %%
test_data = load_data(os.path.join(DATA_DIR, 'test.csv'))
test_data.data = np.ones_like(test_data.data)

# %%
# alpha = 10 gives the best validation performance
print 'Test Recall@20: %.4f' % rec_eval.recall_at_k(train_data, test_data, U_best, V_best, k=20, vad_data=vad_data)
print 'Test Recall@50: %.4f' % rec_eval.recall_at_k(train_data, test_data, U_best, V_best, k=50, vad_data=vad_data)
print 'Test NDCG@100: %.4f' % rec_eval.normalized_dcg_at_k(train_data, test_data, U_best, V_best, k=100, vad_data=vad_data)
print 'Test MAP@100: %.4f' % rec_eval.map_at_k(train_data, test_data, U_best, V_best, k=100, vad_data=vad_data)
# Out:
# rec_eval.py:184: RuntimeWarning: invalid value encountered in divide
#   recall = tmp / np.minimum(k, X_true_binary.sum(axis=1))
# Test Recall@20: 0.1338
# Test Recall@50: 0.1650
# Test NDCG@100: 0.1603
# Test MAP@100: 0.0474

# %%
np.savez('WMF_K100_ML20M.npz', U=U_best, V=V_best)

# %%
U[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7b21bd0445f8> in <module>()
# ----> 1 U[0]
#
# NameError: name 'U' is not defined

# %%
# one off
num_factors = 100
num_iters = 50
batch_size = 1000

n_jobs = 4
lam_theta = lam_beta = 1e-5

best_ndcg = -np.inf
U_best = None
V_best = None
best_alpha = 0

for alpha in [10]: 
    S = content_wmf.linear_surplus_confidence_matrix(train_data, alpha=alpha)

    U, V, vad_ndcg = content_wmf.factorize(S, num_factors, vad_data=vad_data, num_iters=num_iters, 
                                           init_std=0.01, lambda_U_reg=lam_theta, lambda_V_reg=lam_beta, 
                                           dtype='float32', random_state=98765, verbose=True, 
                                           recompute_factors=batched_inv_joblib.recompute_factors_batched, 
                                           batch_size=batch_size, n_jobs=n_jobs)
    if vad_ndcg > best_ndcg:
        best_ndcg = vad_ndcg
        U_best = U.copy()
        V_best = V.copy()
        best_alpha = alpha
# Out:
# Precompute S^T (if necessary)
#   took 0.148 seconds
# Iteration 0:
# 	Updating user factors: time=16.41
# 	Updating item factors: time=3.77
# 	Validation NDCG@k: 0.19086
# Iteration 1:
# 	Updating user factors: time=16.61
# 	Updating item factors: time=3.92
# 	Validation NDCG@k: 0.31008
# Iteration 2:
# 	Updating user factors: time=16.72
# 	Updating item factors: time=4.24
# 	Validation NDCG@k: 0.32825
# Iteration 3:
# 	Updating user factors: time=17.78
# 	Updating item factors: time=3.77
# 	Validation NDCG@k: 0.33675
# Iteration 4:
# 	Updating user factors: time=16.91
# 	Updating item factors: time=4.02
# 	Validation NDCG@k: 0.34171
# Iteration 5:
# 	Updating user factors: time=16.87
# 	Updating item factors: time=4.17
# 	Validation NDCG@k: 0.34491
# Iteration 6:
# 	Updating user factors: time=16.94
# 	Updating item factors: time=4.32
# 	Validation NDCG@k: 0.34729
# Iteration 7:
# 	Updating user factors: time=16.74
# 	Updating item factors: time=3.77
# 	Validation NDCG@k: 0.34894
# Iteration 8:
# 	Updating user factors: time=16.79
# 	Updating item factors: time=3.95
# 	Validation NDCG@k: 0.35018
# Iteration 9:
# 	Updating user factors: time=16.82
# 	Updating item factors: time=3.89
# 	Validation NDCG@k: 0.35112
# Iteration 10:
# 	Updating user factors: time=16.82
# 	Updating item factors: time=3.84
# 	Validation NDCG@k: 0.35193
# Iteration 11:
# 	Updating user factors: time=17.75
# 	Updating item factors: time=4.20
# 	Validation NDCG@k: 0.35252
# Iteration 12:
# 	Updating user factors: time=17.00
# 	Updating item factors: time=3.96
# 	Validation NDCG@k: 0.35301
# Iteration 13:
# 	Updating user factors: time=16.88
# 	Updating item factors: time=3.97
# 	Validation NDCG@k: 0.35341
# Iteration 14:
# 	Updating user factors: time=16.80
# 	Updating item factors: time=3.81
# 	Validation NDCG@k: 0.35376
# Iteration 15:
# 	Updating user factors: time=17.73
# 	Updating item factors: time=3.93
# 	Validation NDCG@k: 0.35401
# Iteration 16:
# 	Updating user factors: time=16.94
# 	Updating item factors: time=4.20
# 	Validation NDCG@k: 0.35425
# Iteration 17:
# 	Updating user factors: time=16.82
# 	Updating item factors: time=4.01
# 	Validation NDCG@k: 0.35432
# Iteration 18:
# 	Updating user factors: time=17.02
# 	Updating item factors: time=3.92
# 	Validation NDCG@k: 0.35450
# Iteration 19:
# 	Updating user factors: time=16.82
# 	Updating item factors: time=3.89
# 	Validation NDCG@k: 0.35468
# Iteration 20:
# 	Updating user factors: time=16.70
# 	Updating item factors: time=3.90
# 	Validation NDCG@k: 0.35480
# Iteration 21:
# 	Updating user factors: time=16.85
# 	Updating item factors: time=4.23
# 	Validation NDCG@k: 0.35488
# Iteration 22:
# 	Updating user factors: time=17.45
# 	Updating item factors: time=3.95
# 	Validation NDCG@k: 0.35495
# Iteration 23:
# 	Updating user factors: time=16.78
# 	Updating item factors: time=3.82
# 	Validation NDCG@k: 0.35495

# %%
# alpha = 10 gives the best validation performance
print 'Test Recall@20: %.4f' % rec_eval.recall_at_k(train_data, test_data, U_best, V_best, k=20, vad_data=vad_data)
print 'Test Recall@50: %.4f' % rec_eval.recall_at_k(train_data, test_data, U_best, V_best, k=50, vad_data=vad_data)
print 'Test NDCG@100: %.4f' % rec_eval.normalized_dcg_at_k(train_data, test_data, U_best, V_best, k=100, vad_data=vad_data)
